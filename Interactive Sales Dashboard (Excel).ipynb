# %% [markdown]
# # Interactive Sales Dashboard (Excel)

# %% [markdown]
# ## Objective
# To deliver a comprehensive, easy-to-use reporting tool that helps business stakeholders monitor overall performance and make data-driven decisions on sales trends, profitability, and product contribution.

# %% [markdown]
# ## What This Dashboard Offers
# - **Executive-Level Insights:**\
# Track total sales, profit, and margin performance over time with clear KPI indicators and trend charts.
#
# - **Product-Level Analysis:**\
# Drill down into top-performing products by sales and profit, explore product categories, and visualize product contributions using treemaps and bar charts.

# %% [markdown]
# ## Sales Dashboard

# %% [markdown]
# ![Sales DB.png](attachment:b00b44bd-4004-4f84-8eeb-6602afa897a2.png)

# %% [markdown]
# ## Product Dashboard

# %% [markdown]
# ![Product DB.png](attachment:bdfef83b-4658-44ab-9d19-1bd3c3319487.png)

# %%
from IPython.display import YouTubeVideo

# Embed the video using the video ID
YouTubeVideo('PWPq9_tZrMo', width=900, height=500)

# %% [markdown]
# ### Key Features
# - Interactive slicers for region, group, and date filtering.
# - KPI cards for quick-glance metrics (Total Sales, Profit $, Profit %).
# - Time-based visualizations (monthly line chart, quarterly bar chart).
# - Treemap for product share of sales and category breakdowns for strategic analysis.
# - Seamless navigation between executive and product-focused views.

# %% [markdown]
# ### Insights
# - Which regions and time periods drive the most revenue and profit.
# - Which products and categories are most profitable or underperforming.
# - How cost structure impacts overall margin.

# %% [markdown]
# Link: https://docs.google.com/spreadsheets/d/1ffHsuzJlyA5RHWRCTMVdgehT9456krQD/edit?usp=sharing&ouid=105667349614326379611&rtpof=true&sd=true
